# %%
# !pip install igraph
# !pip install pyvis jinja2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 39.8 MB/s eta 0:00:00
# ...

# %%
from igraph import Graph
from pyvis.network import Network

# Create the graph using igraph
grafo = Graph(directed=True)

nodes = {
  "Nodes": [

    {
      "id": "TextGeneration",
      "name": "Text Generation",
      "category": "Application",
      "description": "Using generative AI models to produce coherent text, such as articles, poetry, or dialogue.",
      "parent": "GenerativeAI"
    },
    {
      "id": "ImageGeneration",
      "name": "Image Generation",
      "category": "Application",
      "description": "Creating new images using learned patterns from training data, often via GANs or diffusion models.",
      "parent": "GenerativeAI"
    },
    {
      "id": "AudioGeneration",
      "name": "Audio Generation",
      "category": "Application",
      "description": "Synthesizing new audio or speech, typically by learning patterns from large collections of sound data.",
      "parent": "GenerativeAI"
    },
    {
      "id": "VideoGeneration",
      "name": "Video Generation",
      "category": "Application",
      "description": "Producing new video content, frame by frame, through generative models trained on video datasets.",
      "parent": "GenerativeAI"
    },
    {
      "id": "CodeGeneration",
      "name": "Code Generation",
      "category": "Application",
      "description": "Automatically generating programming code snippets or entire functions from text prompts or examples.",
      "parent": "GenerativeAI"
    },

    {
      "id": "InstructionTuning",
      "name": "Instruction Tuning",
      "category": "Concept",
      "description": "A fine-tuning approach where models are trained on instruction-like data to better follow user prompts.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "FewShotLearning",
      "name": "Few-Shot Learning",
      "category": "Concept",
      "description": "An approach where a model adapts to new tasks or data using only a small number of labeled examples.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "ZeroShotLearning",
      "name": "Zero-Shot Learning",
      "category": "Concept",
      "description": "Enabling a model to handle tasks or classes it was never explicitly trained on by leveraging learned general knowledge.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "ReinforcementLearningFromHumanFeedback",
      "name": "Reinforcement Learning from Human Feedback (RLHF)",
      "category": "Concept",
      "description": "A method of improving model alignment and responses by incorporating direct human preference signals as rewards.",
      "parent": "LargeLanguageModels"
    },

    {
      "id": "LoRA",
      "name": "Low-Rank Adaptation (LoRA)",
      "category": "Algorithm",
      "description": "A parameter-efficient technique for fine-tuning large models by adding low-rank adapters to certain layers.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "AdaLoRA",
      "name": "Adaptive Low-Rank Adaptation (AdaLoRA)",
      "category": "Algorithm",
      "description": "A variant of LoRA that adaptively adjusts low-rank parameterization during fine-tuning for better performance.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "LoHa",
      "name": "Low-Rank Hadamard Product (LoHa)",
      "category": "Algorithm",
      "description": "A fine-tuning approach applying low-rank factorization with Hadamard products to reduce model parameters.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "PromptTuning",
      "name": "Prompt Tuning",
      "category": "Algorithm",
      "description": "A technique that learns prompt tokens or embeddings to guide large language models toward desired outputs.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "PrefixTuning",
      "name": "Prefix Tuning",
      "category": "Algorithm",
      "description": "A technique that prepends learnable vectors (prefixes) to the hidden states of large models for parameter-efficient fine-tuning.",
      "parent": "OptimizationMethods"
    },

    {
      "id": "PPO",
      "name": "Proximal Policy Optimization (PPO)",
      "category": "Algorithm",
      "description": "A popular reinforcement learning algorithm that performs multiple epochs of gradient ascent on clipped objective functions.",
      "parent": "ReinforcementLearning"
    },
    {
      "id": "DPO",
      "name": "Deterministic Policy Optimization (DPO)",
      "category": "Algorithm",
      "description": "A variant of policy optimization where the policy is deterministic, often used in high-dimensional action spaces.",
      "parent": "ReinforcementLearning"
    },
    {
      "id": "RLOO",
      "name": "Reinforce Leave-One-Out (RLOO)",
      "category": "Algorithm",
      "description": "A reinforcement learning technique that updates policy by leaving out one trajectory at each update step.",
      "parent": "ReinforcementLearning"
    },
    {
      "id": "IPO",
      "name": "Identity Preference Optimization (IPO)",
      "category": "Algorithm",
      "description": "A specialized RL method focusing on aligning a model's behavior with a user's identity, preferences, or constraints.",
      "parent": "ReinforcementLearning"
    },
    {
      "id": "RLAIF",
      "name": "Reinforcement Learning with Auxiliary Information Feedback (RLAIF)",
      "category": "Algorithm",
      "description": "An RL approach that incorporates additional context or user feedback signals to guide policy updates.",
      "parent": "ReinforcementLearning"
    },

    {
      "id": "OrthogonalFineTuning",
      "name": "Orthogonal Fine-Tuning (OFT)",
      "category": "Algorithm",
      "description": "A method of fine-tuning that keeps updates orthogonal to previously learned directions, mitigating catastrophic forgetting.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "KahnemanTverskyOptimization",
      "name": "Kahneman-Tversky Optimization (KTO)",
      "category": "Algorithm",
      "description": "An experimental optimization approach inspired by human decision-making heuristics (prospect theory) for policy updates.",
      "parent": "OptimizationMethods"
    },

    {
      "id": "ChainOfThought",
      "name": "Chain of Thought (CoT)",
      "category": "Concept",
      "description": "A reasoning approach in which the model explicitly enumerates intermediate steps to arrive at a final answer.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "MemoryManagement",
      "name": "Memory Management",
      "category": "Concept",
      "description": "Techniques for storing, retrieving, or refreshing context in large language models to maintain coherence over extended discourse.",
      "parent": "LargeLanguageModels"
    },

    {
      "id": "RetrievalAugmentedGeneration",
      "name": "Retrieval-Augmented Generation (RAG)",
      "category": "Approach",
      "description": "Combines a retriever for relevant context with a generative model, enabling more accurate and grounded answers.",
      "parent": "GenerativeAI"
    },
    {
      "id": "MultiqueryRetriever",
      "name": "Multiquery Retriever",
      "category": "Tool",
      "description": "A retrieval component that uses multiple queries in parallel or sequentially to gather relevant documents.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "ContextualComprehensionRetriever",
      "name": "Contextual Comprehension Retriever",
      "category": "Tool",
      "description": "A retrieval system that attempts to comprehend the query context for more accurate document selection.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "CustomRetriever",
      "name": "Custom Retriever",
      "category": "Tool",
      "description": "A user-defined or specialized retrieval component tailored to a specific domain or data source.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "EnsembleRetriever",
      "name": "Ensemble Retriever",
      "category": "Tool",
      "description": "Combines multiple retriever modules to improve overall recall and precision in retrieval-augmented generation.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "ParentDocumentRetriever",
      "name": "Parent Document Retriever",
      "category": "Tool",
      "description": "Retrieves top-level or parent documents (rather than small chunks) to preserve broad context.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "MultivectorRetriever",
      "name": "Multivector Retriever",
      "category": "Tool",
      "description": "Uses multiple vector representations per document to capture varied semantic aspects, improving recall.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "VectorDatabases",
      "name": "Vector Databases",
      "category": "Tool",
      "description": "Database systems optimized for storing and querying vector embeddings, key for retrieval-augmented methods.",
      "parent": "RetrievalAugmentedGeneration"
    },
    {
      "id": "Pinecone",
      "name": "Pinecone",
      "category": "Framework",
      "description": "A managed vector database service for storing and searching high-dimensional embeddings.",
      "parent": "VectorDatabases"
    },
    {
      "id": "Chroma",
      "name": "Chroma",
      "category": "Framework",
      "description": "An open-source vector database and embedding store designed for ease of integration with AI models.",
      "parent": "VectorDatabases"
    },
    {
      "id": "Weaviate",
      "name": "Weaviate",
      "category": "Framework",
      "description": "A cloud-native, modular, and real-time vector search engine that incorporates semantic search and classification.",
      "parent": "VectorDatabases"
    },
    {
      "id": "OpenSearch",
      "name": "OpenSearch",
      "category": "Framework",
      "description": "A community-driven, open-source search and analytics suite that supports vector search functionalities.",
      "parent": "VectorDatabases"
    },
    {
      "id": "AzureCognitiveSearch",
      "name": "Azure Cognitive Search",
      "category": "Framework",
      "description": "A Microsoft Azure service offering natural language processing and vector-based search capabilities.",
      "parent": "VectorDatabases"
    },

    {
      "id": "AgentsAndAutonomousSystems",
      "name": "Agents and Autonomous Systems",
      "category": "Subfield",
      "description": "Systems that can perform tasks or make decisions with minimal human intervention, leveraging AI planning and reasoning.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "RuleBasedAgents",
      "name": "Rule-Based Agents",
      "category": "Approach",
      "description": "Agents that follow predefined rules or logic to make decisions and take actions.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ReactiveAgents",
      "name": "Reactive Agents",
      "category": "Approach",
      "description": "Agents that respond to stimuli or changes in the environment in real time without long-term planning.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "DeliberativeAgents",
      "name": "Deliberative Agents",
      "category": "Approach",
      "description": "Agents that use internal models, planning, and reasoning to select actions toward a specific goal.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "HybridAgents",
      "name": "Hybrid Agents",
      "category": "Approach",
      "description": "Agents combining reactive and deliberative approaches, enabling both quick responses and long-term planning.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "ZeroShotReActAgents",
      "name": "Zero-Shot ReAct Agents",
      "category": "Architecture",
      "description": "Agents that combine zero-shot learning with a 'React' framework, allowing them to handle new tasks without additional training.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ConversationalAgents",
      "name": "Conversational Agents",
      "category": "Architecture",
      "description": "Agents designed specifically for dialogue and interaction with users in a conversational manner.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "TaskOrientedAgents",
      "name": "Task-Oriented Agents",
      "category": "Architecture",
      "description": "Agents focused on achieving specific tasks or goals, often using structured inputs and outputs.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "HybridMemoryAgents",
      "name": "Hybrid Memory Agents",
      "category": "Architecture",
      "description": "Agents that leverage both short-term and long-term memory stores to make decisions over extended interactions.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ToolIntegratedAgents",
      "name": "Tool-Integrated Agents",
      "category": "Architecture",
      "description": "Agents that can dynamically incorporate external APIs, databases, or computational tools into their decision-making process.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "SearchAndRetrievalTool",
      "name": "Search and Retrieval",
      "category": "Tool",
      "description": "A module or capability in agents to find and retrieve relevant information from external sources or knowledge bases.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "APIIntegrationTool",
      "name": "API Integration",
      "category": "Tool",
      "description": "Allows an agent to call external services or APIs to extend functionality (e.g., querying databases, performing transactions).",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ReasoningAndPlanningTool",
      "name": "Reasoning and Planning",
      "category": "Tool",
      "description": "A module enabling agents to perform logical inference and plan sequences of actions toward a goal.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "DataManipulationAndConversionTool",
      "name": "Data Manipulation and Conversion",
      "category": "Tool",
      "description": "A utility for agents to transform, format, or clean data to make it suitable for further processing.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "ShortTermMemory",
      "name": "Short-term Memory",
      "category": "Concept",
      "description": "Memory that stores recent states, interactions, or observations for quick access in agent decision-making.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "LongTermMemory",
      "name": "Long-term Memory",
      "category": "Concept",
      "description": "Memory that persists information for extended durations, allowing an agent to accumulate knowledge over time.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "EpisodicMemory",
      "name": "Episodic Memory",
      "category": "Concept",
      "description": "Memory of specific events or episodes, often including contextual details like time and place.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "SemanticMemory",
      "name": "Semantic Memory",
      "category": "Concept",
      "description": "Memory that captures generalized facts, concepts, and relationships rather than specific experiences.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "TaskDecomposition",
      "name": "Task Decomposition",
      "category": "Function",
      "description": "The process of breaking down a high-level goal or instruction into smaller, more manageable subtasks.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ToolSelection",
      "name": "Tool Selection",
      "category": "Function",
      "description": "An agent’s process of choosing the appropriate external tool or API for solving a given sub-problem.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ActionExecution",
      "name": "Action Execution",
      "category": "Function",
      "description": "Carrying out the selected action or tool operation as part of the agent’s workflow.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "ResultIntegration",
      "name": "Result Integration",
      "category": "Function",
      "description": "Combining results from external tools or modules back into the agent's reasoning or conversation flow.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "AutoGen",
      "name": "AutoGen",
      "category": "Framework",
      "description": "A framework for building autonomous AI agents capable of planning, reasoning, and tool usage.",
      "parent": "AgentsAndAutonomousSystems"
    },
    {
      "id": "CrewAI",
      "name": "CrewAI",
      "category": "Framework",
      "description": "A platform or library that facilitates multi-agent coordination and orchestration for various tasks.",
      "parent": "AgentsAndAutonomousSystems"
    },

    {
      "id": "Perplexity",
      "name": "Perplexity",
      "category": "Metric",
      "description": "A measure of how well a probability model predicts a sample, commonly used to evaluate language models.",
      "parent": "BenchmarksAndEvaluation"
    },
    {
      "id": "BLEUScore",
      "name": "BLEU Score",
      "category": "Metric",
      "description": "Bilingual Evaluation Understudy, a metric for evaluating the quality of machine-translated text against references.",
      "parent": "BenchmarksAndEvaluation"
    },
    {
      "id": "ROUGEScore",
      "name": "ROUGE Score",
      "category": "Metric",
      "description": "Recall-Oriented Understudy for Gisting Evaluation, a set of metrics for evaluating text summarization quality.",
      "parent": "BenchmarksAndEvaluation"
    },
    {
      "id": "F1Score",
      "name": "F1 Score",
      "category": "Metric",
      "description": "The harmonic mean of precision and recall, used as a measure of a model’s accuracy on a given task.",
      "parent": "BenchmarksAndEvaluation"
    },
    {
      "id": "HumanEvaluation",
      "name": "Human Evaluation",
      "category": "Metric",
      "description": "Assessment of model outputs by human judges, often used to gauge fluency, coherence, or correctness.",
      "parent": "BenchmarksAndEvaluation"
    },

    {
      "id": "Hallucination",
      "name": "Hallucination",
      "category": "Challenge",
      "description": "When a model generates details or facts that are not grounded in the provided context or knowledge base.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "BiasAndFairness",
      "name": "Bias and Fairness",
      "category": "Challenge",
      "description": "Concerns around models producing biased or unfair outputs due to imbalanced training data or unintended stereotypes.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "ContextWindowLimitations",
      "name": "Context Window Limitations",
      "category": "Challenge",
      "description": "Issues arising when models cannot process or remember context beyond their maximum token or sequence length.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "ComputationalResources",
      "name": "Computational Resources",
      "category": "Challenge",
      "description": "Limitations in hardware or software that make training and deploying large models expensive or infeasible.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "DataQualityAndQuantity",
      "name": "Data Quality and Quantity",
      "category": "Challenge",
      "description": "Challenges stemming from insufficient or noisy datasets, which hamper model performance and generalization.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "InterpretabilityAndExplainability",
      "name": "Interpretability and Explainability",
      "category": "Challenge",
      "description": "The difficulty in understanding or explaining how complex AI models arrive at their decisions or outputs.",
      "parent": "AIEthicsSafetyAndGovernance"
    },

    {
      "id": "PrivacyAndDataProtection",
      "name": "Privacy and Data Protection",
      "category": "Ethics",
      "description": "Safeguarding user data and ensuring models do not expose sensitive information or violate confidentiality.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "Transparency",
      "name": "Transparency",
      "category": "Ethics",
      "description": "The principle of disclosing how AI systems function, process data, and make decisions, fostering trust.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "Accountability",
      "name": "Accountability",
      "category": "Ethics",
      "description": "Ensuring that developers, organizations, or systems can be held responsible for the outcomes of AI actions.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "EnvironmentalImpact",
      "name": "Environmental Impact",
      "category": "Ethics",
      "description": "Concerns regarding the energy consumption and carbon footprint associated with large-scale AI training.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "SocietalImpact",
      "name": "Societal Impact",
      "category": "Ethics",
      "description": "The broader effects AI can have on social structures, employment, communication, and culture.",
      "parent": "AIEthicsSafetyAndGovernance"
    },

    {
      "id": "MultimodalModels",
      "name": "Multimodal Models",
      "category": "Concept",
      "description": "Models capable of processing and generating multiple data modalities (text, image, audio, video) in a unified framework.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "ContinualLearning",
      "name": "Continual Learning",
      "category": "Concept",
      "description": "Methods enabling models to learn sequentially from data over time without forgetting previously acquired knowledge.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "QuantumMachineLearningIntegration",
      "name": "Quantum Machine Learning Integration",
      "category": "Concept",
      "description": "Exploring how quantum computing can enhance or accelerate machine learning algorithms and models.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "NeuromorphicComputing",
      "name": "Neuromorphic Computing",
      "category": "Concept",
      "description": "A field aiming to design computer hardware inspired by the structure and function of biological neural systems.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "HumanAICollaboration",
      "name": "Human-AI Collaboration",
      "category": "Concept",
      "description": "Research and techniques focused on how humans and AI systems can work together effectively.",
      "parent": "ArtificialIntelligence"
    },

    {
      "id": "Linguistics",
      "name": "Linguistics",
      "category": "Field",
      "description": "The scientific study of language structure, development, and interpretation, relevant for enhancing NLP models.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "InformationRetrieval",
      "name": "Information Retrieval",
      "category": "Field",
      "description": "Techniques for acquiring relevant information from large document collections or the web, essential for RAG.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },

    {
      "id": "GoogleGemini",
      "name": "Google Gemini",
      "category": "Framework",
      "description": "A next-generation multi-modal AI model and tooling platform developed by Google, integrating advanced LLM capabilities.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "NVIDIAMegatronLM",
      "name": "NVIDIA Megatron-LM",
      "category": "Framework",
      "description": "A framework and model suite by NVIDIA for training large-scale transformer models in a distributed manner.",
      "parent": "FrameworksAndLibraries"
    },

    {
      "id": "DeepLearningAICourses",
      "name": "DeepLearning.AI Courses",
      "category": "Resource",
      "description": "A series of online courses covering modern deep learning techniques, including LLMs and generative AI.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "HuggingFaceDocumentation",
      "name": "Hugging Face Documentation",
      "category": "Resource",
      "description": "Official resources describing usage of Hugging Face libraries and tools for NLP, LLMs, and more.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "arXivPapersOnLLMsAndGenerativeAI",
      "name": "arXiv Papers on LLMs and Generative AI",
      "category": "Resource",
      "description": "A collection of preprint research papers focusing on the latest developments in large language models and generative AI.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "AIResearchConferences",
      "name": "AI Research Conferences",
      "category": "Resource",
      "description": "Major conferences such as NeurIPS, ICML, and ACL where cutting-edge AI, LLM, and generative research is published.",
      "parent": "ArtificialIntelligence"
    },


    {
      "id": "ArtificialIntelligence",
      "name": "Artificial Intelligence",
      "category": "Field",
      "description": "The simulation of human intelligence processes by machines, especially computer systems.",
      "related": ["MachineLearning", "DeepLearning", "NaturalLanguageProcessing", "RoboticsAndEmbodiedAI"]
    },
    {
      "id": "DefiningIntelligence",
      "name": "Defining Intelligence",
      "category": "Concept",
      "description": "The process of determining the nature, scope, and definition of intelligence, both human and artificial."
    },
    {
      "id": "GoalsAndApplications",
      "name": "Goals and Applications",
      "category": "Concept",
      "description": "The objectives of AI research and the various practical applications where AI technologies are deployed."
    },
    {
      "id": "ApproachesToAI",
      "name": "Approaches to AI",
      "category": "Concept",
      "description": "Different methodologies and paradigms used in developing AI systems, such as symbolic AI, connectionism, and evolutionary algorithms."
    },
    {
      "id": "AIEthicsSafetyAndGovernance",
      "name": "AI Ethics, Safety, and Governance",
      "category": "Ethics",
      "description": "The study and implementation of ethical principles, safety measures, and governance frameworks to ensure responsible AI development and deployment."
    },
    {
      "id": "MachineLearning",
      "name": "Machine Learning",
      "category": "Subfield",
      "description": "A subset of AI that focuses on the development of algorithms that allow computers to learn from and make decisions based on data.",
      "parent": "ArtificialIntelligence",
      "related": ["DeepLearning", "SupervisedLearning", "UnsupervisedLearning", "ReinforcementLearning"]
    },
    {
      "id": "FundamentalConceptsML",
      "name": "Fundamental Concepts of ML",
      "category": "Concept",
      "description": "Basic principles and ideas that underpin machine learning, including data representation, learning algorithms, and evaluation metrics.",
      "parent": "MachineLearning"
    },
    {
      "id": "TraditionalMachineLearningAlgorithms",
      "name": "Traditional ML Algorithms",
      "category": "Algorithm",
      "description": "Classic machine learning algorithms such as linear regression, logistic regression, k-nearest neighbors, and support vector machines.",
      "parent": "MachineLearning"
    },
    {
      "id": "NeuralNetworks",
      "name": "Neural Networks",
      "category": "Model",
      "description": "Computational models inspired by the human brain, consisting of interconnected nodes (neurons) that process information.",
      "parent": "MachineLearning",
      "related": ["DeepLearning", "ArtificialNeuralNetworks"]
    },
    {
      "id": "DecisionTrees",
      "name": "Decision Trees",
      "category": "Algorithm",
      "description": "A tree-like model used for decision making and classification tasks, where each internal node represents a decision based on feature values.",
      "parent": "TraditionalMachineLearningAlgorithms"
    },
    {
      "id": "RandomForests",
      "name": "Random Forests",
      "category": "Algorithm",
      "description": "An ensemble learning method that constructs multiple decision trees and combines their outputs to improve accuracy and prevent overfitting.",
      "parent": "TraditionalMachineLearningAlgorithms",
      "related": ["DecisionTrees"]
    },
    {
      "id": "SupportVectorMachines",
      "name": "Support Vector Machines",
      "category": "Algorithm",
      "description": "A supervised learning model that analyzes data for classification and regression by finding the optimal hyperplane that separates classes.",
      "parent": "TraditionalMachineLearningAlgorithms"
    },
    {
      "id": "DeepLearning",
      "name": "Deep Learning",
      "category": "Subfield",
      "description": "A subset of machine learning involving neural networks with many layers, capable of learning complex patterns in large datasets.",
      "parent": "MachineLearning",
      "related": ["NeuralNetworks", "ConvolutionalNeuralNetworks", "RecurrentNeuralNetworks"]
    },
    {
      "id": "FundamentalConceptsDL",
      "name": "Fundamental Concepts of DL",
      "category": "Concept",
      "description": "Basic principles and ideas that underpin deep learning, including network architecture, backpropagation, and activation functions.",
      "parent": "DeepLearning"
    },
    {
      "id": "ArtificialNeuralNetworks",
      "name": "Artificial Neural Networks",
      "category": "Model",
      "description": "A network of artificial neurons that mimic the neural structure of the human brain to process data and generate outputs.",
      "parent": "NeuralNetworks",
      "related": ["ConvolutionalNeuralNetworks", "RecurrentNeuralNetworks"]
    },
    {
      "id": "ConvolutionalNeuralNetworks",
      "name": "Convolutional Neural Networks",
      "category": "Model",
      "description": "A type of neural network particularly effective for processing grid-like data such as images, utilizing convolutional layers to detect features.",
      "parent": "ArtificialNeuralNetworks",
      "related": ["ComputerVision"]
    },
    {
      "id": "RecurrentNeuralNetworks",
      "name": "Recurrent Neural Networks",
      "category": "Model",
      "description": "A class of neural networks where connections between nodes form directed cycles, enabling the processing of sequential data.",
      "parent": "ArtificialNeuralNetworks",
      "related": ["NaturalLanguageProcessing"]
    },
    {
      "id": "GraphNeuralNetworks",
      "name": "Graph Neural Networks",
      "category": "Model",
      "description": "Neural networks that operate on graph structures, effectively capturing relationships and interactions between nodes.",
      "parent": "ArtificialNeuralNetworks",
      "related": ["KnowledgeGraphs"]
    },
    {
      "id": "Autoencoders",
      "name": "Autoencoders",
      "category": "Model",
      "description": "A type of neural network used for unsupervised learning, primarily for dimensionality reduction and feature learning by encoding and decoding data.",
      "parent": "ArtificialNeuralNetworks",
      "related": ["VariationalAutoencoders"]
    },
    {
      "id": "GenerativeAI",
      "name": "Generative AI",
      "category": "Subfield",
      "description": "AI systems designed to generate new content, such as text, images, or music, by learning patterns from existing data.",
      "parent": "ArtificialIntelligence",
      "related": ["GenerativeAdversarialNetworks", "VariationalAutoencoders", "Transformers"]
    },
    {
      "id": "GenerativeAdversarialNetworks",
      "name": "Generative Adversarial Networks",
      "category": "Model",
      "description": "A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete to generate realistic data.",
      "parent": "GenerativeAI",
      "related": ["DeepLearning"]
    },
    {
      "id": "VariationalAutoencoders",
      "name": "Variational Autoencoders",
      "category": "Model",
      "description": "A type of autoencoder that learns a probabilistic representation of the input data, enabling the generation of new, similar data points.",
      "parent": "GenerativeAI",
      "related": ["Autoencoders"]
    },
    {
      "id": "FlowBasedModels",
      "name": "Flow-Based Models",
      "category": "Model",
      "description": "Generative models that use invertible transformations to map data to a latent space, allowing for exact log-likelihood computation.",
      "parent": "GenerativeAI"
    },
    {
      "id": "DiffusionModels",
      "name": "Diffusion Models",
      "category": "Model",
      "description": "Generative models that learn to reverse a diffusion process, gradually transforming noise into coherent data samples.",
      "parent": "GenerativeAI"
    },
    {
      "id": "Transformers",
      "name": "Transformers",
      "category": "Model",
      "description": "A neural network architecture that relies on self-attention mechanisms to process sequential data, widely used in NLP and other fields.",
      "parent": "DeepLearning",
      "related": ["AttentionMechanism", "EncoderDecoderArchitecture"]
    },
    {
      "id": "AttentionMechanism",
      "name": "Attention Mechanism",
      "category": "Concept",
      "description": "A technique in neural networks that allows the model to focus on specific parts of the input sequence when generating each part of the output.",
      "parent": "Transformers",
      "related": ["SelfAttention"]
    },
    {
      "id": "EncoderDecoderArchitecture",
      "name": "Encoder-Decoder Architecture",
      "category": "Architecture",
      "description": "A neural network design that consists of two parts: an encoder that processes the input and a decoder that generates the output.",
      "parent": "Transformers",
      "related": ["SequenceToSequence"]
    },
    {
      "id": "TransformerVariants",
      "name": "Transformer Variants",
      "category": "Model",
      "description": "Different adaptations and improvements of the original transformer architecture, such as BERT, GPT, and T5.",
      "parent": "Transformers",
      "related": ["LargeLanguageModels"]
    },
    {
      "id": "OptimizationMethods",
      "name": "Optimization Methods",
      "category": "Concept",
      "description": "Techniques used to adjust the parameters of machine learning models to minimize or maximize an objective function.",
      "related": ["GradientDescent", "SecondOrderOptimizationMethods"]
    },
    {
      "id": "GradientDescent",
      "name": "Gradient Descent",
      "category": "Algorithm",
      "description": "An optimization algorithm that iteratively adjusts model parameters in the opposite direction of the gradient of the loss function.",
      "parent": "OptimizationMethods",
      "related": ["VariantsOfGradientDescent"]
    },
    {
      "id": "VariantsOfGradientDescent",
      "name": "Variants of Gradient Descent",
      "category": "Algorithm",
      "description": "Different modifications of the basic gradient descent algorithm, including Stochastic Gradient Descent, Mini-batch Gradient Descent, and others.",
      "parent": "GradientDescent"
    },
    {
      "id": "SecondOrderOptimizationMethods",
      "name": "Second-Order Optimization Methods",
      "category": "Algorithm",
      "description": "Optimization techniques that utilize second-order derivatives (Hessian) to achieve faster convergence, such as Newton's method and L-BFGS.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "OptimizationTechniquesForTransformers",
      "name": "Optimization Techniques for Transformers",
      "category": "Concept",
      "description": "Specialized optimization strategies tailored to improve the training efficiency and performance of transformer-based models.",
      "parent": "Transformers"
    },
    {
      "id": "TrainingModalities",
      "name": "Training Modalities",
      "category": "Concept",
      "description": "Different approaches to training machine learning models, including supervised, unsupervised, semi-supervised, self-supervised, and reinforcement learning.",
      "related": ["SupervisedLearning", "UnsupervisedLearning", "SemiSupervisedLearning", "SelfSupervisedLearning", "ReinforcementLearning"]
    },
    {
      "id": "SupervisedLearning",
      "name": "Supervised Learning",
      "category": "Training Modality",
      "description": "A machine learning approach where the model is trained on labeled data, learning to map inputs to desired outputs.",
      "parent": "TrainingModalities"
    },
    {
      "id": "UnsupervisedLearning",
      "name": "Unsupervised Learning",
      "category": "Training Modality",
      "description": "A machine learning approach where the model learns patterns and structures from unlabeled data.",
      "parent": "TrainingModalities"
    },
    {
      "id": "SemiSupervisedLearning",
      "name": "Semi-Supervised Learning",
      "category": "Training Modality",
      "description": "A machine learning approach that combines a small amount of labeled data with a large amount of unlabeled data during training.",
      "parent": "TrainingModalities"
    },
    {
      "id": "SelfSupervisedLearning",
      "name": "Self-Supervised Learning",
      "category": "Training Modality",
      "description": "A machine learning approach where the model generates its own labels from the data, enabling learning without explicit annotations.",
      "parent": "TrainingModalities"
    },
    {
      "id": "ReinforcementLearning",
      "name": "Reinforcement Learning",
      "category": "Training Modality",
      "description": "A machine learning approach where an agent learns to make decisions by performing actions and receiving rewards or penalties.",
      "parent": "TrainingModalities",
      "related": ["TransferLearning"]
    },
    {
      "id": "TransferLearning",
      "name": "Transfer Learning",
      "category": "Training Modality",
      "description": "A machine learning technique where knowledge gained from one task is applied to improve learning in a related but different task.",
      "parent": "TrainingModalities",
      "related": ["ReinforcementLearning"]
    },
    {
      "id": "KnowledgeRepresentationAndReasoning",
      "name": "Knowledge Representation and Reasoning",
      "category": "Subfield",
      "description": "A branch of AI focused on how knowledge can be represented symbolically and how automated reasoning can be performed on these representations.",
      "parent": "ArtificialIntelligence",
      "related": ["LogicBasedSystems", "SemanticNetworksAndOntologies"]
    },
    {
      "id": "LogicBasedSystems",
      "name": "Logic-Based Systems",
      "category": "Approach",
      "description": "AI systems that use formal logic to represent knowledge and perform reasoning.",
      "parent": "KnowledgeRepresentationAndReasoning",
      "related": ["PropositionalLogic", "PredicateLogic"]
    },
    {
      "id": "PropositionalLogic",
      "name": "Propositional Logic",
      "category": "Logic",
      "description": "A branch of logic dealing with propositions and their relationships using logical connectives.",
      "parent": "LogicBasedSystems"
    },
    {
      "id": "PredicateLogic",
      "name": "Predicate Logic",
      "category": "Logic",
      "description": "An extension of propositional logic that includes quantifiers and predicates, allowing for more expressive representations.",
      "parent": "LogicBasedSystems"
    },
    {
      "id": "DescriptionLogics",
      "name": "Description Logics",
      "category": "Logic",
      "description": "A family of formal knowledge representation languages designed for representing structured knowledge and supporting automated reasoning.",
      "parent": "LogicBasedSystems"
    },
    {
      "id": "SemanticNetworksAndOntologies",
      "name": "Semantic Networks and Ontologies",
      "category": "Approach",
      "description": "Methods for representing knowledge in networks of concepts and relationships (semantic networks) and formalized frameworks of knowledge (ontologies).",
      "parent": "KnowledgeRepresentationAndReasoning",
      "related": ["KnowledgeGraphs"]
    },
    {
      "id": "KnowledgeGraphs",
      "name": "Knowledge Graphs",
      "category": "Model",
      "description": "Graph-based representations of knowledge where entities are nodes and relationships are edges, facilitating efficient querying and reasoning.",
      "parent": "SemanticNetworksAndOntologies",
      "related": ["GraphNeuralNetworks"]
    },
    {
      "id": "ExpertSystems",
      "name": "Expert Systems",
      "category": "Application",
      "description": "AI systems that emulate the decision-making ability of a human expert, using a knowledge base and inference rules.",
      "parent": "ArtificialIntelligence"
    },
    {
      "id": "ReasoningTechniques",
      "name": "Reasoning Techniques",
      "category": "Concept",
      "description": "Methods used by AI systems to derive logical conclusions from available knowledge.",
      "related": ["Deduction", "Induction", "Abduction"]
    },
    {
      "id": "Deduction",
      "name": "Deduction",
      "category": "Reasoning Technique",
      "description": "A logical process where conclusions are drawn from a set of premises that are assumed to be true.",
      "parent": "ReasoningTechniques"
    },
    {
      "id": "Induction",
      "name": "Induction",
      "category": "Reasoning Technique",
      "description": "A logical process where generalizations are made based on specific observations or instances.",
      "parent": "ReasoningTechniques"
    },
    {
      "id": "Abduction",
      "name": "Abduction",
      "category": "Reasoning Technique",
      "description": "A logical process of forming explanatory hypotheses, inferring the most likely explanation from incomplete observations.",
      "parent": "ReasoningTechniques"
    },
    {
      "id": "CommonSenseReasoning",
      "name": "Common Sense Reasoning",
      "category": "Reasoning Technique",
      "description": "The ability of AI systems to make presumptions about the world that humans take for granted, enabling more natural interactions.",
      "parent": "ReasoningTechniques"
    },
    {
      "id": "RoboticsAndEmbodiedAI",
      "name": "Robotics and Embodied AI",
      "category": "Subfield",
      "description": "The study and creation of intelligent agents embodied in physical robots, capable of interacting with the physical world.",
      "parent": "ArtificialIntelligence",
      "related": ["Perception", "PlanningAndControl", "HumanRobotInteraction"]
    },
    {
      "id": "Perception",
      "name": "Perception",
      "category": "Function",
      "description": "The process by which robots and AI systems interpret sensory information to understand their environment.",
      "parent": "RoboticsAndEmbodiedAI",
      "related": ["ComputerVision", "PoseEstimation"]
    },
    {
      "id": "ComputerVision",
      "name": "Computer Vision",
      "category": "Subfield",
      "description": "A field of AI that enables machines to interpret and make decisions based on visual data from the world.",
      "parent": "Perception",
      "related": ["ImageClassificationAndObjectDetection", "ImageSegmentation"]
    },
    {
      "id": "PlanningAndControl",
      "name": "Planning and Control",
      "category": "Function",
      "description": "Techniques used by robots to plan actions and control movements to achieve specific goals.",
      "parent": "RoboticsAndEmbodiedAI",
      "related": ["LocomotionAndManipulation"]
    },
    {
      "id": "LocomotionAndManipulation",
      "name": "Locomotion and Manipulation",
      "category": "Function",
      "description": "The ability of robots to move within and interact with their environment through walking, grasping, and other actions.",
      "parent": "RoboticsAndEmbodiedAI"
    },
    {
      "id": "HumanRobotInteraction",
      "name": "Human-Robot Interaction",
      "category": "Function",
      "description": "The study and design of interactions between humans and robots to ensure effective and natural communication.",
      "parent": "RoboticsAndEmbodiedAI"
    },
    {
      "id": "NaturalLanguageProcessing",
      "name": "Natural Language Processing",
      "category": "Subfield",
      "description": "A field of AI focused on the interaction between computers and humans through natural language.",
      "parent": "ArtificialIntelligence",
      "related": ["LanguageModeling", "MachineTranslation", "QuestionAnswering"]
    },
    {
      "id": "FundamentalTasksNLP",
      "name": "Fundamental Tasks in NLP",
      "category": "Concept",
      "description": "Basic tasks in natural language processing, including morphological analysis, syntactic analysis, semantic analysis, and more.",
      "parent": "NaturalLanguageProcessing",
      "related": ["MorphologicalAnalysis", "SyntacticAnalysis", "SemanticAnalysis"]
    },
    {
      "id": "MorphologicalAnalysis",
      "name": "Morphological Analysis",
      "category": "Task",
      "description": "The process of analyzing the structure of words to understand their components and formation.",
      "parent": "FundamentalTasksNLP"
    },
    {
      "id": "SyntacticAnalysis",
      "name": "Syntactic Analysis",
      "category": "Task",
      "description": "The process of analyzing the grammatical structure of sentences to understand the relationships between words.",
      "parent": "FundamentalTasksNLP"
    },
    {
      "id": "SemanticAnalysis",
      "name": "Semantic Analysis",
      "category": "Task",
      "description": "The process of understanding the meaning and interpretation of words and sentences in context.",
      "parent": "FundamentalTasksNLP"
    },
    {
      "id": "LanguageModeling",
      "name": "Language Modeling",
      "category": "Task",
      "description": "The process of developing models that can predict the probability of a sequence of words, useful for various NLP applications.",
      "parent": "NaturalLanguageProcessing",
      "related": ["LargeLanguageModels"]
    },
    {
      "id": "TextClassificationAndSentimentAnalysis",
      "name": "Text Classification and Sentiment Analysis",
      "category": "Task",
      "description": "Techniques for categorizing text into predefined classes and determining the sentiment expressed within the text.",
      "parent": "NaturalLanguageProcessing"
    },
    {
      "id": "NamedEntityRecognition",
      "name": "Named Entity Recognition",
      "category": "Task",
      "description": "The process of identifying and classifying proper nouns in text into predefined categories such as names, organizations, locations, etc.",
      "parent": "NaturalLanguageProcessing"
    },
    {
      "id": "MachineTranslation",
      "name": "Machine Translation",
      "category": "Task",
      "description": "The automatic translation of text or speech from one language to another using AI models.",
      "parent": "NaturalLanguageProcessing",
      "related": ["Transformers"]
    },
    {
      "id": "QuestionAnswering",
      "name": "Question Answering",
      "category": "Task",
      "description": "Systems designed to automatically answer questions posed by humans in natural language.",
      "parent": "NaturalLanguageProcessing",
      "related": ["Transformers"]
    },
    {
      "id": "TextSummarization",
      "name": "Text Summarization",
      "category": "Task",
      "description": "The process of creating a concise and coherent summary of a longer text document using AI techniques.",
      "parent": "NaturalLanguageProcessing"
    },
    {
      "id": "DialogueSystemsAndConversationalAI",
      "name": "Dialogue Systems and Conversational AI",
      "category": "Application",
      "description": "AI systems designed to engage in natural language conversations with humans, including chatbots and virtual assistants.",
      "parent": "NaturalLanguageProcessing",
      "related": ["Transformers"]
    },
    {
      "id": "ImageClassificationAndObjectDetection",
      "name": "Image Classification and Object Detection",
      "category": "Task",
      "description": "Techniques in computer vision for categorizing images and identifying and locating objects within them.",
      "parent": "ComputerVision"
    },
    {
      "id": "ImageSegmentation",
      "name": "Image Segmentation",
      "category": "Task",
      "description": "The process of partitioning an image into multiple segments to simplify or change its representation for easier analysis.",
      "parent": "ComputerVision"
    },
    {
      "id": "ImageGenerationAndEditing",
      "name": "Image Generation and Editing",
      "category": "Task",
      "description": "Techniques for creating new images from scratch or modifying existing ones using AI models.",
      "parent": "ComputerVision",
      "related": ["GenerativeAdversarialNetworks"]
    },
    {
      "id": "VideoAnalysis",
      "name": "Video Analysis",
      "category": "Task",
      "description": "Techniques for processing and interpreting video data, including action recognition, tracking, and event detection.",
      "parent": "ComputerVision"
    },
    {
      "id": "PoseEstimation",
      "name": "Pose Estimation",
      "category": "Task",
      "description": "The process of detecting and tracking the pose of objects or humans within images or videos.",
      "parent": "ComputerVision"
    },
    {
      "id": "PlanningAndDecisionMaking",
      "name": "Planning and Decision Making",
      "category": "Function",
      "description": "AI techniques for generating sequences of actions to achieve specific goals based on current knowledge and predictions.",
      "related": ["SearchAlgorithms", "GamePlayingAI"]
    },
    {
      "id": "SearchAlgorithms",
      "name": "Search Algorithms",
      "category": "Algorithm",
      "description": "Algorithms designed to traverse or search through data structures or problem spaces to find solutions or optimal paths.",
      "parent": "PlanningAndDecisionMaking"
    },
    {
      "id": "GamePlayingAI",
      "name": "Game Playing AI",
      "category": "Application",
      "description": "AI systems designed to play games, utilizing strategies and decision-making algorithms to compete against human or other AI players.",
      "parent": "PlanningAndDecisionMaking",
      "related": ["MonteCarloTreeSearch"]
    },
    {
      "id": "MonteCarloTreeSearch",
      "name": "Monte Carlo Tree Search",
      "category": "Algorithm",
      "description": "A heuristic search algorithm used for decision-making processes, particularly in game playing, by randomly sampling the search space.",
      "parent": "GamePlayingAI"
    },
    {
      "id": "FrameworksAndLibraries",
      "name": "Frameworks and Libraries",
      "category": "Tool",
      "description": "Software frameworks and libraries that provide tools and functionalities to develop and deploy AI models.",
      "related": ["TensorFlow", "PyTorch", "HuggingFace"]
    },
    {
      "id": "TensorFlow",
      "name": "TensorFlow",
      "category": "Framework",
      "description": "An open-source machine learning framework developed by Google for building and deploying machine learning models.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "PyTorch",
      "name": "PyTorch",
      "category": "Framework",
      "description": "An open-source machine learning library developed by Facebook's AI Research lab, known for its flexibility and ease of use.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "HuggingFace",
      "name": "Hugging Face",
      "category": "Library",
      "description": "A library providing tools and pre-trained models for natural language processing, including the popular Transformers library.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "GraphsInAI",
      "name": "Graphs in AI",
      "category": "Concept",
      "description": "The use of graph structures to represent and process data in various AI applications, facilitating the modeling of relationships.",
      "related": ["ComputationGraphs", "StateSpaceGraphs", "BayesianNetworks"]
    },
    {
      "id": "ComputationGraphs",
      "name": "Computation Graphs",
      "category": "Concept",
      "description": "Graph-based representations of mathematical computations, where nodes represent operations and edges represent data flow.",
      "parent": "GraphsInAI"
    },
    {
      "id": "StateSpaceGraphs",
      "name": "State-Space Graphs",
      "category": "Concept",
      "description": "Graphs representing states and transitions in problem-solving scenarios, useful in planning and search algorithms.",
      "parent": "GraphsInAI"
    },
    {
      "id": "BayesianNetworks",
      "name": "Bayesian Networks",
      "category": "Model",
      "description": "Probabilistic graphical models that represent a set of variables and their conditional dependencies using a directed acyclic graph.",
      "parent": "GraphsInAI"
    },
    {
      "id": "BenchmarksAndEvaluation",
      "name": "Benchmarks and Evaluation",
      "category": "Concept",
      "description": "Standards and metrics used to assess the performance and effectiveness of AI models and systems.",
      "related": ["LargeLanguageModels", "VisionLanguageModels"]
    },
    {
      "id": "LargeLanguageModels",
      "name": "Large Language Models",
      "category": "Model",
      "description": "Extensive neural network models trained on vast amounts of text data, capable of understanding and generating human-like language.",
      "parent": "BenchmarksAndEvaluation",
      "related": ["Transformers", "GLUE", "SuperGLUE", "MMLU"]
    },
    {
      "id": "GLUE",
      "name": "GLUE",
      "category": "Benchmark",
      "description": "General Language Understanding Evaluation, a benchmark for evaluating the performance of natural language processing models.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "SuperGLUE",
      "name": "SuperGLUE",
      "category": "Benchmark",
      "description": "An advanced version of GLUE, designed to be more challenging and better assess the capabilities of language models.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "MMLU",
      "name": "MMLU",
      "category": "Benchmark",
      "description": "Massive Multitask Language Understanding, a benchmark that evaluates models across a wide range of subjects and tasks.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "HellaSwag",
      "name": "HellaSwag",
      "category": "Benchmark",
      "description": "A benchmark for commonsense reasoning and understanding, designed to test a model's ability to predict the most plausible continuation of a story.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "ARC",
      "name": "ARC",
      "category": "Benchmark",
      "description": "AI2 Reasoning Challenge, a set of tasks designed to evaluate the reasoning abilities of AI models.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "BigBench",
      "name": "BigBench",
      "category": "Benchmark",
      "description": "A comprehensive benchmark designed to evaluate the capabilities of large language models across a diverse set of tasks.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "VisionLanguageModels",
      "name": "Vision-Language Models",
      "category": "Model",
      "description": "AI models that integrate both visual and textual data to perform tasks that require understanding of both modalities.",
      "parent": "BenchmarksAndEvaluation",
      "related": ["VQA", "NLVR2", "MS_COCO_Captions"]
    },
    {
      "id": "VQA",
      "name": "VQA",
      "category": "Benchmark",
      "description": "Visual Question Answering, a task that requires models to answer questions based on the content of images.",
      "parent": "VisionLanguageModels"
    },
    {
      "id": "NLVR2",
      "name": "NLVR2",
      "category": "Benchmark",
      "description": "Natural Language for Visual Reasoning, a dataset and benchmark for evaluating the ability of models to reason about language and images together.",
      "parent": "VisionLanguageModels"
    },
    {
      "id": "MS_COCO_Captions",
      "name": "MS COCO Captions",
      "category": "Dataset",
      "description": "A dataset of images with corresponding descriptive captions, commonly used for training and evaluating image captioning models.",
      "parent": "VisionLanguageModels"
    },
    {
      "id": "Flickr30k_Entities",
      "name": "Flickr30k Entities",
      "category": "Dataset",
      "description": "A dataset containing images with detailed annotations of entities mentioned in associated textual descriptions.",
      "parent": "VisionLanguageModels"
    },
    {
      "id": "MMMU",
      "name": "MMMU",
      "category": "Benchmark",
      "description": "A multilingual multi-modal understanding benchmark designed to evaluate models across various languages and modalities.",
      "parent": "VisionLanguageModels"
    },
    {
      "id": "ReasoningModels",
      "name": "Reasoning Models",
      "category": "Concept",
      "description": "AI models designed to perform logical reasoning, problem-solving, and decision-making tasks.",
      "related": ["BigBenchHard", "LogicalDeductionTasks"]
    },
    {
      "id": "BigBenchHard",
      "name": "BigBench Hard",
      "category": "Benchmark",
      "description": "A subset of the BigBench benchmark focused on more challenging tasks that require advanced reasoning capabilities.",
      "parent": "ReasoningModels"
    },
    {
      "id": "LogicalDeductionTasks",
      "name": "Logical Deduction Tasks",
      "category": "Benchmark",
      "description": "Tasks that evaluate a model's ability to perform logical deductions and infer conclusions from given premises.",
      "parent": "ReasoningModels"
    },
    {
      "id": "CommonSenseReasoningBenchmarks",
      "name": "Common Sense Reasoning Benchmarks",
      "category": "Benchmark",
      "description": "Benchmarks designed to assess a model's ability to apply common sense knowledge to understand and reason about everyday scenarios.",
      "parent": "ReasoningModels"
    },
    {
      "id": "CrossCuttingConcernsAndRelatedFields",
      "name": "Cross-Cutting Concerns and Related Fields",
      "category": "Concept",
      "description": "Topics and disciplines that intersect with AI, influencing its development and application.",
      "related": ["DataEngineeringAndManagement", "CognitiveScienceAndNeuroscience"]
    },
    {
      "id": "DataEngineeringAndManagement",
      "name": "Data Engineering and Management",
      "category": "Field",
      "description": "The practice of designing, building, and maintaining systems for collecting, storing, and analyzing data.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "HighPerformanceComputingAndDistributedTraining",
      "name": "High-Performance Computing and Distributed Training",
      "category": "Field",
      "description": "Techniques and infrastructures for scaling AI model training across multiple processors and machines to handle large datasets and complex models.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "CloudComputingForAI",
      "name": "Cloud Computing for AI",
      "category": "Field",
      "description": "The use of cloud-based resources and services to develop, deploy, and scale AI applications.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "EdgeAI",
      "name": "Edge AI",
      "category": "Field",
      "description": "AI processing performed on local devices (edge devices) rather than centralized cloud servers, enabling faster response times and improved privacy.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "InternetOfThingsAndAI",
      "name": "Internet of Things and AI",
      "category": "Field",
      "description": "The integration of AI with IoT devices to enable intelligent data processing and decision-making at the edge.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "ExplainableAI",
      "name": "Explainable AI",
      "category": "Field",
      "description": "AI systems designed to provide understandable and interpretable explanations for their decisions and actions.",
      "parent": "CrossCuttingConcernsAndRelatedFields",
      "related": ["AIEthicsSafetyAndGovernance"]
    },
    {
      "id": "AISafetyAndSecurity",
      "name": "AI Safety and Security",
      "category": "Field",
      "description": "The study and implementation of measures to ensure AI systems operate safely, securely, and without unintended harmful consequences.",
      "parent": "CrossCuttingConcernsAndRelatedFields",
      "related": ["AIEthicsSafetyAndGovernance"]
    },
    {
      "id": "CognitiveScienceAndNeuroscience",
      "name": "Cognitive Science and Neuroscience",
      "category": "Field",
      "description": "Interdisciplinary studies focused on understanding the mind and brain, influencing AI research through insights into human cognition and neural processes.",
      "parent": "CrossCuttingConcernsAndRelatedFields"
    },
    {
      "id": "PromptEngineering",
      "name": "Prompt Engineering",
      "category": "Concept",
      "description": "The practice of designing, crafting, and iterating on input prompts to guide large language models toward more accurate or relevant outputs.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "InContextLearning",
      "name": "In-Context Learning",
      "category": "Concept",
      "description": "A phenomenon in large language models where they can adapt to new tasks or information presented within the prompt itself, without explicit parameter updates.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "OneShotLearning",
      "name": "One-Shot Learning",
      "category": "Concept",
      "description": "An approach where a model can generalize from a single training example, closely related to few-shot learning but with only one example.",
      "parent": "LargeLanguageModels"
    },
    {
      "id": "KnowledgeDistillation",
      "name": "Knowledge Distillation",
      "category": "Algorithm",
      "description": "A technique to compress large models by transferring knowledge from a high-capacity teacher model to a smaller student model.",
      "parent": "OptimizationMethods"
    },
    {
      "id": "SyntheticDataGeneration",
      "name": "Synthetic Data Generation",
      "category": "Application",
      "description": "Using generative AI models to create artificial datasets for training or testing, often to augment real data and improve robustness.",
      "parent": "GenerativeAI"
    },
    {
      "id": "SelfPlay",
      "name": "Self-Play",
      "category": "Algorithm",
      "description": "A reinforcement learning technique where an agent improves by competing or collaborating with its own copies, removing the need for external data.",
      "parent": "ReinforcementLearning"
    },
    {
      "id": "AdversarialMachineLearning",
      "name": "Adversarial Machine Learning",
      "category": "Challenge",
      "description": "The study of how ML models can be manipulated or attacked through adversarial examples and how to make them more robust against such threats.",
      "parent": "AIEthicsSafetyAndGovernance"
    },
    {
      "id": "LangChain",
      "name": "LangChain",
      "category": "Framework",
      "description": "An open-source framework facilitating the creation of end-to-end applications that combine large language models with retrieval, tool usage, and chaining techniques.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "LLamaIndex",
      "name": "LLamaIndex",
      "category": "Framework",
      "description": "A framework providing data connectors and indexing capabilities to help large language models access, retrieve, and reason over external data sources.",
      "parent": "FrameworksAndLibraries"
    },
    {
      "id": "OpenAIAPI",
      "name": "OpenAI API",
      "category": "Framework",
      "description": "A set of cloud-based APIs for accessing OpenAI’s large language models and related services, enabling text generation, embeddings, and more.",
      "parent": "FrameworksAndLibraries"
    }

  ]
}

edges = [
    ("ArtificialIntelligence", "DefiningIntelligence", "has_subfield"),
    ("ArtificialIntelligence", "GoalsAndApplications", "has_subfield"),
    ("ArtificialIntelligence", "ApproachesToAI", "has_subfield"),
    ("ArtificialIntelligence", "AIEthicsSafetyAndGovernance", "has_subfield"),
    ("MachineLearning", "ArtificialIntelligence", "is_subfield_of"),
    ("MachineLearning", "FundamentalConceptsML", "has_part"),
    ("MachineLearning", "TraditionalMachineLearningAlgorithms", "has_part"),
    ("TraditionalMachineLearningAlgorithms", "NeuralNetworks", "includes"),
    ("TraditionalMachineLearningAlgorithms", "DecisionTrees", "includes"),
    ("TraditionalMachineLearningAlgorithms", "RandomForests", "includes"),
    ("TraditionalMachineLearningAlgorithms", "SupportVectorMachines", "includes"),
    ("DeepLearning", "MachineLearning", "is_subfield_of"),
    ("DeepLearning", "FundamentalConceptsDL", "has_part"),
    ("DeepLearning", "ArtificialNeuralNetworks", "has_part"),
    ("DeepLearning", "ConvolutionalNeuralNetworks", "has_part"),
    ("DeepLearning", "RecurrentNeuralNetworks", "has_part"),
    ("DeepLearning", "GraphNeuralNetworks", "has_part"),
    ("DeepLearning", "Autoencoders", "has_part"),
    ("GenerativeAI", "DeepLearning", "is_part_of"),
    ("GenerativeAI", "GenerativeAdversarialNetworks", "includes"),
    ("GenerativeAI", "VariationalAutoencoders", "includes"),
    ("GenerativeAI", "FlowBasedModels", "includes"),
    ("GenerativeAI", "DiffusionModels", "includes"),
    ("Transformers", "DeepLearning", "is_part_of"),
    ("Transformers", "AttentionMechanism", "has_part"),
    ("Transformers", "EncoderDecoderArchitecture", "has_part"),
    ("Transformers", "TransformerVariants", "has_part"),
    ("OptimizationMethods", "MachineLearning", "are_used_in"),
    ("OptimizationMethods", "DeepLearning", "are_used_in"),
    ("OptimizationMethods", "GradientDescent", "has_part"),
    ("OptimizationMethods", "VariantsOfGradientDescent", "has_part"),
    ("OptimizationMethods", "SecondOrderOptimizationMethods", "has_part"),
    ("OptimizationMethods", "OptimizationTechniquesForTransformers", "has_part"),
    ("TrainingModalities", "MachineLearning", "are_used_in"),
    ("TrainingModalities", "DeepLearning", "are_used_in"),
    ("TrainingModalities", "SupervisedLearning", "includes"),
    ("TrainingModalities", "UnsupervisedLearning", "includes"),
    ("TrainingModalities", "SemiSupervisedLearning", "includes"),
    ("TrainingModalities", "SelfSupervisedLearning", "includes"),
    ("TrainingModalities", "ReinforcementLearning", "includes"),
    ("TrainingModalities", "TransferLearning", "includes"),
    ("KnowledgeRepresentationAndReasoning", "ArtificialIntelligence", "is_subfield_of"),
    ("KnowledgeRepresentationAndReasoning", "LogicBasedSystems", "has_part"),
    ("LogicBasedSystems", "PropositionalLogic", "includes"),
    ("LogicBasedSystems", "PredicateLogic", "includes"),
    ("LogicBasedSystems", "DescriptionLogics", "includes"),
    ("KnowledgeRepresentationAndReasoning", "SemanticNetworksAndOntologies", "has_part"),
    ("KnowledgeRepresentationAndReasoning", "KnowledgeGraphs", "has_part"),
    ("KnowledgeRepresentationAndReasoning", "ExpertSystems", "has_part"),
    ("KnowledgeRepresentationAndReasoning", "ReasoningTechniques", "has_part"),
    ("ReasoningTechniques", "Deduction", "includes"),
    ("ReasoningTechniques", "Induction", "includes"),
    ("ReasoningTechniques", "Abduction", "includes"),
    ("ReasoningTechniques", "CommonSenseReasoning", "includes"),
    ("RoboticsAndEmbodiedAI", "ArtificialIntelligence", "is_subfield_of"),
    ("RoboticsAndEmbodiedAI", "Perception", "has_part"),
    ("Perception", "ComputerVision", "uses"),
    ("RoboticsAndEmbodiedAI", "PlanningAndControl", "has_part"),
    ("PlanningAndControl", "SearchAlgorithms", "uses"),
    ("RoboticsAndEmbodiedAI", "LocomotionAndManipulation", "has_part"),
    ("RoboticsAndEmbodiedAI", "HumanRobotInteraction", "has_part"),
    ("NaturalLanguageProcessing", "ArtificialIntelligence", "is_subfield_of"),
    ("NaturalLanguageProcessing", "FundamentalTasksNLP", "has_part"),
    ("FundamentalTasksNLP", "MorphologicalAnalysis", "includes"),
    ("FundamentalTasksNLP", "SyntacticAnalysis", "includes"),
    ("FundamentalTasksNLP", "SemanticAnalysis", "includes"),
    ("NaturalLanguageProcessing", "LanguageModeling", "has_part"),
    ("LanguageModeling", "LargeLanguageModels", "includes"),
    ("NaturalLanguageProcessing", "TextClassificationAndSentimentAnalysis", "has_part"),
    ("NaturalLanguageProcessing", "NamedEntityRecognition", "has_part"),
    ("NaturalLanguageProcessing", "MachineTranslation", "has_part"),
    ("NaturalLanguageProcessing", "QuestionAnswering", "has_part"),
    ("NaturalLanguageProcessing", "TextSummarization", "has_part"),
    ("NaturalLanguageProcessing", "DialogueSystemsAndConversationalAI", "has_part"),
    ("ComputerVision", "ArtificialIntelligence", "is_subfield_of"),
    ("ComputerVision", "ImageClassificationAndObjectDetection", "has_part"),
    ("ComputerVision", "ImageSegmentation", "has_part"),
    ("ComputerVision", "ImageGenerationAndEditing", "has_part"),
    ("ComputerVision", "VideoAnalysis", "has_part"),
    ("ComputerVision", "PoseEstimation", "has_part"),
    ("PlanningAndDecisionMaking", "ArtificialIntelligence", "is_subfield_of"),
    ("PlanningAndDecisionMaking", "SearchAlgorithms", "has_part"),
    ("SearchAlgorithms", "GamePlayingAI", "includes"),
    ("SearchAlgorithms", "MonteCarloTreeSearch", "includes"),
    ("FrameworksAndLibraries", "MachineLearning", "implements"),
    ("FrameworksAndLibraries", "DeepLearning", "implements"),
    ("FrameworksAndLibraries", "TensorFlow", "includes"),
    ("FrameworksAndLibraries", "PyTorch", "includes"),
    ("FrameworksAndLibraries", "HuggingFace", "includes"),
    ("GraphsInAI", "ArtificialIntelligence", "are_used_in"),
    ("GraphsInAI", "KnowledgeGraphs", "has_part"),
    ("GraphsInAI", "ComputationGraphs", "has_part"),
    ("GraphsInAI", "GraphNeuralNetworks", "has_part"),
    ("GraphsInAI", "StateSpaceGraphs", "has_part"),
    ("GraphsInAI", "BayesianNetworks", "has_part"),
    ("BenchmarksAndEvaluation", "MachineLearning", "evaluate"),
    ("BenchmarksAndEvaluation", "DeepLearning", "evaluate"),
    ("BenchmarksAndEvaluation", "LargeLanguageModels", "includes"),
    ("LargeLanguageModels", "GLUE", "includes"),
    ("LargeLanguageModels", "SuperGLUE", "includes"),
    ("LargeLanguageModels", "MMLU", "includes"),
    ("LargeLanguageModels", "HellaSwag", "includes"),
    ("LargeLanguageModels", "ARC", "includes"),
    ("LargeLanguageModels", "BigBench", "includes"),
    ("BenchmarksAndEvaluation", "VisionLanguageModels", "includes"),
    ("VisionLanguageModels", "VQA", "includes"),
    ("VisionLanguageModels", "NLVR2", "includes"),
    ("VisionLanguageModels", "MS_COCO_Captions", "includes"),
    ("VisionLanguageModels", "Flickr30k_Entities", "includes"),
    ("VisionLanguageModels", "MMMU", "includes"),
    ("BenchmarksAndEvaluation", "ReasoningModels", "includes"),
    ("ReasoningModels", "BigBenchHard", "includes"),
    ("ReasoningModels", "LogicalDeductionTasks", "includes"),
    ("ReasoningModels", "CommonSenseReasoningBenchmarks", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "ArtificialIntelligence", "relate_to"),
    ("CrossCuttingConcernsAndRelatedFields", "DataEngineeringAndManagement", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "HighPerformanceComputingAndDistributedTraining", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "CloudComputingForAI", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "EdgeAI", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "InternetOfThingsAndAI", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "ExplainableAI", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "AISafetyAndSecurity", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "CognitiveScienceAndNeuroscience", "includes"),

    ("GenerativeAI", "TextGeneration", "includes"),
    ("GenerativeAI", "ImageGeneration", "includes"),
    ("GenerativeAI", "AudioGeneration", "includes"),
    ("GenerativeAI", "VideoGeneration", "includes"),
    ("GenerativeAI", "CodeGeneration", "includes"),

    ("LargeLanguageModels", "InstructionTuning", "includes"),
    ("LargeLanguageModels", "FewShotLearning", "includes"),
    ("LargeLanguageModels", "ZeroShotLearning", "includes"),
    ("LargeLanguageModels", "ReinforcementLearningFromHumanFeedback", "includes"),

    ("OptimizationMethods", "LoRA", "has_part"),
    ("OptimizationMethods", "AdaLoRA", "has_part"),
    ("OptimizationMethods", "LoHa", "has_part"),
    ("OptimizationMethods", "PromptTuning", "has_part"),
    ("OptimizationMethods", "PrefixTuning", "has_part"),
    ("OptimizationMethods", "OrthogonalFineTuning", "has_part"),
    ("OptimizationMethods", "KahnemanTverskyOptimization", "has_part"),

    ("ReinforcementLearning", "PPO", "includes"),
    ("ReinforcementLearning", "DPO", "includes"),
    ("ReinforcementLearning", "RLOO", "includes"),
    ("ReinforcementLearning", "IPO", "includes"),
    ("ReinforcementLearning", "RLAIF", "includes"),
    ("LargeLanguageModels", "ChainOfThought", "has_part"),
    ("LargeLanguageModels", "MemoryManagement", "has_part"),
    ("GenerativeAI", "RetrievalAugmentedGeneration", "includes"),
    ("RetrievalAugmentedGeneration", "MultiqueryRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "ContextualComprehensionRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "CustomRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "EnsembleRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "ParentDocumentRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "MultivectorRetriever", "has_part"),
    ("RetrievalAugmentedGeneration", "VectorDatabases", "has_part"),
    ("VectorDatabases", "Pinecone", "includes"),
    ("VectorDatabases", "Chroma", "includes"),
    ("VectorDatabases", "Weaviate", "includes"),
    ("VectorDatabases", "OpenSearch", "includes"),
    ("VectorDatabases", "AzureCognitiveSearch", "includes"),
    ("AgentsAndAutonomousSystems", "ArtificialIntelligence", "is_subfield_of"),
    ("AgentsAndAutonomousSystems", "RuleBasedAgents", "includes"),
    ("AgentsAndAutonomousSystems", "ReactiveAgents", "includes"),
    ("AgentsAndAutonomousSystems", "DeliberativeAgents", "includes"),
    ("AgentsAndAutonomousSystems", "HybridAgents", "includes"),
    ("AgentsAndAutonomousSystems", "ZeroShotReActAgents", "includes"),
    ("AgentsAndAutonomousSystems", "ConversationalAgents", "includes"),
    ("AgentsAndAutonomousSystems", "TaskOrientedAgents", "includes"),
    ("AgentsAndAutonomousSystems", "HybridMemoryAgents", "includes"),
    ("AgentsAndAutonomousSystems", "ToolIntegratedAgents", "includes"),
    ("AgentsAndAutonomousSystems", "SearchAndRetrievalTool", "includes"),
    ("AgentsAndAutonomousSystems", "APIIntegrationTool", "includes"),
    ("AgentsAndAutonomousSystems", "ReasoningAndPlanningTool", "includes"),
    ("AgentsAndAutonomousSystems", "DataManipulationAndConversionTool", "includes"),
    ("AgentsAndAutonomousSystems", "ShortTermMemory", "includes"),
    ("AgentsAndAutonomousSystems", "LongTermMemory", "includes"),
    ("AgentsAndAutonomousSystems", "EpisodicMemory", "includes"),
    ("AgentsAndAutonomousSystems", "SemanticMemory", "includes"),
    ("AgentsAndAutonomousSystems", "TaskDecomposition", "includes"),
    ("AgentsAndAutonomousSystems", "ToolSelection", "includes"),
    ("AgentsAndAutonomousSystems", "ActionExecution", "includes"),
    ("AgentsAndAutonomousSystems", "ResultIntegration", "includes"),
    ("AgentsAndAutonomousSystems", "AutoGen", "includes"),
    ("AgentsAndAutonomousSystems", "CrewAI", "includes"),
    ("BenchmarksAndEvaluation", "Perplexity", "includes"),
    ("BenchmarksAndEvaluation", "BLEUScore", "includes"),
    ("BenchmarksAndEvaluation", "ROUGEScore", "includes"),
    ("BenchmarksAndEvaluation", "F1Score", "includes"),
    ("BenchmarksAndEvaluation", "HumanEvaluation", "includes"),
    ("AIEthicsSafetyAndGovernance", "Hallucination", "includes"),
    ("AIEthicsSafetyAndGovernance", "BiasAndFairness", "includes"),
    ("AIEthicsSafetyAndGovernance", "ContextWindowLimitations", "includes"),
    ("AIEthicsSafetyAndGovernance", "ComputationalResources", "includes"),
    ("AIEthicsSafetyAndGovernance", "DataQualityAndQuantity", "includes"),
    ("AIEthicsSafetyAndGovernance", "InterpretabilityAndExplainability", "includes"),
    ("AIEthicsSafetyAndGovernance", "PrivacyAndDataProtection", "includes"),
    ("AIEthicsSafetyAndGovernance", "Transparency", "includes"),
    ("AIEthicsSafetyAndGovernance", "Accountability", "includes"),
    ("AIEthicsSafetyAndGovernance", "EnvironmentalImpact", "includes"),
    ("AIEthicsSafetyAndGovernance", "SocietalImpact", "includes"),
    ("ArtificialIntelligence", "MultimodalModels", "includes"),
    ("ArtificialIntelligence", "ContinualLearning", "includes"),
    ("ArtificialIntelligence", "QuantumMachineLearningIntegration", "includes"),
    ("ArtificialIntelligence", "NeuromorphicComputing", "includes"),
    ("ArtificialIntelligence", "HumanAICollaboration", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "Linguistics", "includes"),
    ("CrossCuttingConcernsAndRelatedFields", "InformationRetrieval", "includes"),
    ("FrameworksAndLibraries", "GoogleGemini", "includes"),
    ("FrameworksAndLibraries", "NVIDIAMegatronLM", "includes"),
    ("ArtificialIntelligence", "DeepLearningAICourses", "includes"),
    ("ArtificialIntelligence", "HuggingFaceDocumentation", "includes"),
    ("ArtificialIntelligence", "arXivPapersOnLLMsAndGenerativeAI", "includes"),
    ("ArtificialIntelligence", "AIResearchConferences", "includes"),
    ("DeepLearning", "NeuralNetworks", "builds_on"),
    ("GenerativeAI", "LargeLanguageModels", "includes"),
    ("LargeLanguageModels", "PromptEngineering", "includes"),
    ("LargeLanguageModels", "InContextLearning", "includes"),
    ("LargeLanguageModels", "OneShotLearning", "includes"),
    ("OptimizationMethods", "KnowledgeDistillation", "has_part"),
    ("GenerativeAI", "SyntheticDataGeneration", "includes"),
    ("ReinforcementLearning", "SelfPlay", "includes"),
    ("AIEthicsSafetyAndGovernance", "AdversarialMachineLearning", "includes"),
    ("FrameworksAndLibraries", "LangChain", "includes"),
    ("FrameworksAndLibraries", "LLamaIndex", "includes"),
    ("FrameworksAndLibraries", "OpenAIAPI", "includes"),
    ("LargeLanguageModels", "PromptEngineering", "includes"),
    ("LargeLanguageModels", "InContextLearning", "includes"),
    ("LargeLanguageModels", "OneShotLearning", "includes"),
    ("OptimizationMethods", "KnowledgeDistillation", "has part"),
    ("GenerativeAI", "SyntheticDataGeneration", "includes"),
    ("ReinforcementLearning", "SelfPlay", "includes"),
    ("AIEthicsSafetyAndGovernance", "AdversarialMachineLearning", "includes"),
    ("FrameworksAndLibraries", "LangChain", "includes"),
    ("FrameworksAndLibraries", "LLamaIndex", "includes"),
    ("FrameworksAndLibraries", "OpenAIAPI", "includes")
]


for node in nodes["Nodes"]:
    grafo.add_vertex(name=node["id"],
                     label=node["name"],
                     category=node["category"],
                     description=node["description"],
                     parent=node.get("parent", None))

# Add edges
for source, target, edge_type in edges:
    grafo.add_edge(source, target, type=edge_type)


# Print the graph summary
print(grafo.summary())


#VISUALIZACION

def export_html(grafo, path="interactive_graph.html"):

  net = Network(directed=True)

  # Add nodes to pyvis Network
  for vertex in grafo.vs:
      net.add_node(vertex.index,
                  label= "Category: "+ str(vertex["name"])+"\nDescription: "+str(vertex["description"]),
                  title=vertex["name"],
                  #value=vertex["value"]
                  )  # Set node size based on value

  # Add edges to pyvis Network
  for edge in grafo.es:
      source = edge.source
      target = edge.target
      edge_type = edge["type"]
      net.add_edge(source, target,
                  title=edge_type,
                  #value=edge["weight"]
                  )  # Set edge width based on weight

  # Configure the layout
  net.repulsion(node_distance=500, spring_length=500)
  net.show_buttons(filter_=["physics"])  # Optional: Add physics configuration options

  # Save and display the interactive graph
  net.save_graph(path)


export_html(grafo, path="interactive_graph.html")
# Out:
# IGRAPH DN-- 214 234 --
# + attr: category (v), description (v), label (v), name (v), parent (v), type (e)

# %%
#Ejemplo buscnado nodos entre SearchAlgorithms y ReinforcementLearning
nodes_to_extract = [grafo.vs.find(name='SearchAlgorithms').index, grafo.vs.find(name="ReinforcementLearning").index, ]


subgrafo = grafo.get_shortest_paths(nodes_to_extract[0], nodes_to_extract[1], mode='auto'
                )
subgrafo = grafo.get_all_shortest_paths(nodes_to_extract[0], nodes_to_extract[1], mode='auto'
                )
for s in subgrafo[0]:
  print(grafo.vs[s]['name'])
# Out:
# SearchAlgorithms
# PlanningAndDecisionMaking
# ArtificialIntelligence
# MachineLearning
# TrainingModalities
# ReinforcementLearning
